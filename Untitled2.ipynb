# %%
# G = float(input("Please enter the valuse of G :"))
# M_earth = float(input("please enter the valuse of M_earth :"))
# M_moon = float(input("Please enter the valuse of M_moon :"))
# r = float(input("Please enter the valuse of r :"))
# FG = (G*M_earth*M_moon)/r
# if G,M_earth,M_moon,r in FG:
#     print(f"result of FG is : {FG}")
# else:
#     print("Erorr please try again later")
##Task 1 page 19 in session 2
def calculate_gravitational_force(G, M_earth, m_moon, r):
    force = (G * M_earth * m_moon) / (r ** 2)
    return force
G = eval(input("Enter the  (G): "))
M_earth = eval(input("Enter the (M): "))
m_moon = eval(input("Enter the  (m): "))
r = eval(input("Enter the (r): "))
gravitational_force = calculate_gravitational_force(G, M_earth, m_moon, r)
print("FG is:", gravitational_force)
# Out:
# Enter the  (G): 4
# Enter the (M): 4
# Enter the  (m): 4
# Enter the (r): 4
# FG is: 4.0

# %%
 for num in range(1,101):
        if num%3==0 and num%5==0:
            print("FizzBuzz")
        elif num%3==0:
            print("Fizz")
        elif num%5==0:
            print("Buzz")
        else:
            print(num)
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz
